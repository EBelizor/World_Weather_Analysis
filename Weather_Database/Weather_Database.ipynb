# %%
# Import dependencies 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a longitude and latitude combination
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# pair them together
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
#Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %% [markdown]
# ### Get the City Weather Data

# %%
# Import Dependencies and Initialize an empty list and Counters.
import requests

# Import the APi Key
import sys 
sys.path.append("..")
from config import weather_api_key

from datetime import datetime

# %%
# Starting URL for for weather map API call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=c45661bf65d270f100a19490c6037b66

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval    ")
print("----------------------------")

# Create counters 
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | hamilton
# Processing Record 2 of Set 1 | port alfred
# Processing Record 3 of Set 1 | nikolskoye
# Processing Record 4 of Set 1 | pevek
# Processing Record 5 of Set 1 | new norfolk
# Processing Record 6 of Set 1 | san patricio
# Processing Record 7 of Set 1 | amargosa
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | hermanus
# Processing Record 14 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 1 | dikson
# Processing Record 16 of Set 1 | provideniya
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | yarim
# Processing Record 19 of Set 1 | beloha
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | hilo
# Processing Record 22 of Set 1 | port elizabeth
# Processing Record 23 of Set 1 | pomabamba
# Processing Record 24 of Set 1 | coffs harbour
# Processing Record 25 of Set 1 | kapaa
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | grindavik
# Processing Record 28 of Set 1 | staryy nadym
# Processing Record 29 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 1 | ribeira grande
# Processing Record 31 of Set 1 | deputatskiy
# Processing Record 32 of Set 1 | hambantota
# Processing Record 33 of Set 1 | sagua la grande
# Processing Record 34 of Set 1 | bolotnoye
# Processing Record 35 of Set 1 | mehamn
# Processing Record 36 of Set 1 | kijang
# Processing Record 37 of Set 1 | abengourou
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | punta arenas
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | torbay
# Processing Record 42 of Set 1 | chumikan
# Processing Record 43 of Set 1 | canyon lake
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | kupino
# Processing Record 46 of Set 1 | qaanaaq
# Processing Record 47 of Set 1 | padang
# Processing Record 48 of Set 1 | chokurdakh
# Processing Record 49 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 1 | taunsa
# Processing Record 1 of Set 2 | jaramana
# City not found. Skipping...
# Processing Record 2 of Set 2 | lorengau
# Processing Record 3 of Set 2 | castro
# Processing Record 4 of Set 2 | erenhot
# Processing Record 5 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 2 | birjand
# Processing Record 7 of Set 2 | kapit
# Processing Record 8 of Set 2 | almeirim
# Processing Record 9 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 2 | broken hill
# Processing Record 11 of Set 2 | saskylakh
# Processing Record 12 of Set 2 | srednekolymsk
# Processing Record 13 of Set 2 | lumphat
# Processing Record 14 of Set 2 | georgetown
# Processing Record 15 of Set 2 | sinegorye
# Processing Record 16 of Set 2 | mahadday weyne
# City not found. Skipping...
# Processing Record 17 of Set 2 | severo-kurilsk
# Processing Record 18 of Set 2 | port augusta
# Processing Record 19 of Set 2 | necochea
# Processing Record 20 of Set 2 | souillac
# Processing Record 21 of Set 2 | roald
# Processing Record 22 of Set 2 | husavik
# Processing Record 23 of Set 2 | opuwo
# Processing Record 24 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 25 of Set 2 | cherskiy
# Processing Record 26 of Set 2 | urla
# Processing Record 27 of Set 2 | fortuna
# Processing Record 28 of Set 2 | wajima
# Processing Record 29 of Set 2 | warrnambool
# Processing Record 30 of Set 2 | puerto escondido
# Processing Record 31 of Set 2 | kysyl-syr
# Processing Record 32 of Set 2 | ponta delgada
# Processing Record 33 of Set 2 | hasaki
# Processing Record 34 of Set 2 | sola
# Processing Record 35 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 2 | mar del plata
# Processing Record 37 of Set 2 | krasnyy chikoy
# Processing Record 38 of Set 2 | katherine
# Processing Record 39 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 2 | saint-philippe
# Processing Record 41 of Set 2 | santa marta
# Processing Record 42 of Set 2 | sorland
# Processing Record 43 of Set 2 | alice town
# Processing Record 44 of Set 2 | popondetta
# Processing Record 45 of Set 2 | richards bay
# Processing Record 46 of Set 2 | geraldton
# Processing Record 47 of Set 2 | coolum beach
# Processing Record 48 of Set 2 | taoudenni
# Processing Record 49 of Set 2 | butaritari
# Processing Record 50 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 3 | east london
# Processing Record 2 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 3 | barrow
# Processing Record 4 of Set 3 | hanzhong
# Processing Record 5 of Set 3 | dingle
# Processing Record 6 of Set 3 | manyana
# Processing Record 7 of Set 3 | el alto
# Processing Record 8 of Set 3 | andilamena
# Processing Record 9 of Set 3 | bathsheba
# Processing Record 10 of Set 3 | nouadhibou
# Processing Record 11 of Set 3 | thompson
# Processing Record 12 of Set 3 | nenjiang
# Processing Record 13 of Set 3 | thinadhoo
# Processing Record 14 of Set 3 | mahebourg
# Processing Record 15 of Set 3 | clyde river
# Processing Record 16 of Set 3 | atuona
# Processing Record 17 of Set 3 | coihaique
# Processing Record 18 of Set 3 | mogadishu
# Processing Record 19 of Set 3 | vanimo
# Processing Record 20 of Set 3 | camacha
# Processing Record 21 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 3 | chulman
# Processing Record 23 of Set 3 | barao de melgaco
# Processing Record 24 of Set 3 | vila franca do campo
# Processing Record 25 of Set 3 | lisakovsk
# Processing Record 26 of Set 3 | orje
# Processing Record 27 of Set 3 | lavras
# Processing Record 28 of Set 3 | pirogovo
# Processing Record 29 of Set 3 | kirkwall
# Processing Record 30 of Set 3 | tilichiki
# Processing Record 31 of Set 3 | chor
# Processing Record 32 of Set 3 | kavieng
# Processing Record 33 of Set 3 | kruisfontein
# Processing Record 34 of Set 3 | evensk
# Processing Record 35 of Set 3 | sitka
# Processing Record 36 of Set 3 | batesville
# Processing Record 37 of Set 3 | arcata
# Processing Record 38 of Set 3 | vardo
# Processing Record 39 of Set 3 | fairlie
# Processing Record 40 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 41 of Set 3 | caucaia
# Processing Record 42 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 3 | faanui
# Processing Record 44 of Set 3 | waddan
# Processing Record 45 of Set 3 | yellowknife
# Processing Record 46 of Set 3 | saint-donat-de-montcalm
# Processing Record 47 of Set 3 | mount isa
# Processing Record 48 of Set 3 | carnarvon
# Processing Record 49 of Set 3 | tuatapere
# Processing Record 50 of Set 3 | aksarka
# Processing Record 1 of Set 4 | emba
# Processing Record 2 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 4 | ferrol
# Processing Record 4 of Set 4 | mogok
# Processing Record 5 of Set 4 | abu ghosh
# Processing Record 6 of Set 4 | tiksi
# Processing Record 7 of Set 4 | pangkalanbuun
# Processing Record 8 of Set 4 | usinsk
# Processing Record 9 of Set 4 | ahipara
# Processing Record 10 of Set 4 | hithadhoo
# Processing Record 11 of Set 4 | formoso do araguaia
# City not found. Skipping...
# Processing Record 12 of Set 4 | vao
# Processing Record 13 of Set 4 | urengoy
# Processing Record 14 of Set 4 | labuhan
# Processing Record 15 of Set 4 | qui nhon
# Processing Record 16 of Set 4 | san cristobal
# Processing Record 17 of Set 4 | komsomolskiy
# Processing Record 18 of Set 4 | esterhazy
# Processing Record 19 of Set 4 | kodiak
# Processing Record 20 of Set 4 | vallenar
# Processing Record 21 of Set 4 | havelock
# Processing Record 22 of Set 4 | puerto ayora
# Processing Record 23 of Set 4 | arraial do cabo
# Processing Record 24 of Set 4 | zahesi
# Processing Record 25 of Set 4 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 26 of Set 4 | avarua
# Processing Record 27 of Set 4 | tasiilaq
# Processing Record 28 of Set 4 | rundu
# Processing Record 29 of Set 4 | ghanzi
# Processing Record 30 of Set 4 | worcester
# Processing Record 31 of Set 4 | kaitangata
# Processing Record 32 of Set 4 | west bay
# Processing Record 33 of Set 4 | broome
# Processing Record 34 of Set 4 | lata
# Processing Record 35 of Set 4 | saint-francois
# Processing Record 36 of Set 4 | tautira
# Processing Record 37 of Set 4 | pacific grove
# Processing Record 38 of Set 4 | honningsvag
# Processing Record 39 of Set 4 | morant bay
# Processing Record 40 of Set 4 | oranjemund
# Processing Record 41 of Set 4 | masvingo
# Processing Record 42 of Set 4 | sorong
# Processing Record 43 of Set 4 | el cobre
# Processing Record 44 of Set 4 | tarakan
# Processing Record 45 of Set 4 | stornoway
# Processing Record 46 of Set 4 | los llanos de aridane
# Processing Record 47 of Set 4 | namtsy
# Processing Record 48 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 4 | ponta do sol
# Processing Record 50 of Set 4 | saint paul
# Processing Record 1 of Set 5 | rio grande
# Processing Record 2 of Set 5 | namibe
# Processing Record 3 of Set 5 | robat karim
# Processing Record 4 of Set 5 | kandry
# Processing Record 5 of Set 5 | ormara
# Processing Record 6 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 5 | leningradskiy
# Processing Record 8 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 5 | bethel
# Processing Record 10 of Set 5 | yerbogachen
# Processing Record 11 of Set 5 | tuktoyaktuk
# Processing Record 12 of Set 5 | alofi
# Processing Record 13 of Set 5 | bengkulu
# Processing Record 14 of Set 5 | kafanchan
# Processing Record 15 of Set 5 | gat
# Processing Record 16 of Set 5 | carutapera
# Processing Record 17 of Set 5 | bucerias
# Processing Record 18 of Set 5 | palmas bellas
# Processing Record 19 of Set 5 | karasjok
# Processing Record 20 of Set 5 | esperance
# Processing Record 21 of Set 5 | fort nelson
# Processing Record 22 of Set 5 | cabo san lucas
# Processing Record 23 of Set 5 | khatanga
# Processing Record 24 of Set 5 | caravelas
# Processing Record 25 of Set 5 | humboldt
# Processing Record 26 of Set 5 | pudozh
# Processing Record 27 of Set 5 | faya
# Processing Record 28 of Set 5 | bambous virieux
# Processing Record 29 of Set 5 | belaya gora
# Processing Record 30 of Set 5 | kasempa
# Processing Record 31 of Set 5 | olhao
# Processing Record 32 of Set 5 | ponyri
# Processing Record 33 of Set 5 | bandarbeyla
# Processing Record 34 of Set 5 | bilma
# Processing Record 35 of Set 5 | dudinka
# Processing Record 36 of Set 5 | airai
# Processing Record 37 of Set 5 | kahului
# Processing Record 38 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 5 | sibenik
# Processing Record 41 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 42 of Set 5 | narsaq
# Processing Record 43 of Set 5 | ilulissat
# Processing Record 44 of Set 5 | haines junction
# Processing Record 45 of Set 5 | kamenka
# Processing Record 46 of Set 5 | lebu
# Processing Record 47 of Set 5 | knysna
# Processing Record 48 of Set 5 | lasa
# Processing Record 49 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 5 | hofn
# Processing Record 1 of Set 6 | wageningen
# Processing Record 2 of Set 6 | tongchuan
# Processing Record 3 of Set 6 | ust-tsilma
# Processing Record 4 of Set 6 | washington
# Processing Record 5 of Set 6 | oyama
# Processing Record 6 of Set 6 | minot
# Processing Record 7 of Set 6 | lompoc
# Processing Record 8 of Set 6 | fare
# Processing Record 9 of Set 6 | foumban
# Processing Record 10 of Set 6 | sinnamary
# Processing Record 11 of Set 6 | halifax
# Processing Record 12 of Set 6 | avera
# Processing Record 13 of Set 6 | half moon bay
# Processing Record 14 of Set 6 | salacgriva
# Processing Record 15 of Set 6 | man
# Processing Record 16 of Set 6 | derzhavinsk
# Processing Record 17 of Set 6 | miramar
# Processing Record 18 of Set 6 | goderich
# Processing Record 19 of Set 6 | luganville
# Processing Record 20 of Set 6 | beringovskiy
# Processing Record 21 of Set 6 | umm durman
# City not found. Skipping...
# Processing Record 22 of Set 6 | gouyave
# Processing Record 23 of Set 6 | springdale
# Processing Record 24 of Set 6 | marrakesh
# Processing Record 25 of Set 6 | constitucion
# Processing Record 26 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 27 of Set 6 | isla mujeres
# Processing Record 28 of Set 6 | norman wells
# Processing Record 29 of Set 6 | salalah
# Processing Record 30 of Set 6 | arrecife
# Processing Record 31 of Set 6 | skagastrond
# City not found. Skipping...
# Processing Record 32 of Set 6 | ngorongoro
# Processing Record 33 of Set 6 | nuevo progreso
# Processing Record 34 of Set 6 | brae
# Processing Record 35 of Set 6 | mahajanga
# Processing Record 36 of Set 6 | sabha
# Processing Record 37 of Set 6 | kasangulu
# Processing Record 38 of Set 6 | high level
# Processing Record 39 of Set 6 | sao filipe
# Processing Record 40 of Set 6 | caohai
# Processing Record 41 of Set 6 | mutsu
# Processing Record 42 of Set 6 | barhi
# Processing Record 43 of Set 6 | laguna
# Processing Record 44 of Set 6 | benton harbor
# Processing Record 45 of Set 6 | tocopilla
# Processing Record 46 of Set 6 | cockburn town
# Processing Record 47 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 48 of Set 6 | dennery
# Processing Record 49 of Set 6 | saint-jean-de-maurienne
# Processing Record 50 of Set 6 | olafsvik
# Processing Record 1 of Set 7 | wanning
# Processing Record 2 of Set 7 | kavaratti
# Processing Record 3 of Set 7 | samarai
# Processing Record 4 of Set 7 | ambunti
# Processing Record 5 of Set 7 | vestmannaeyjar
# Processing Record 6 of Set 7 | tucuman
# Processing Record 7 of Set 7 | esmeraldas
# Processing Record 8 of Set 7 | mount gambier
# Processing Record 9 of Set 7 | unai
# Processing Record 10 of Set 7 | biltine
# Processing Record 11 of Set 7 | maragogi
# Processing Record 12 of Set 7 | wakefield
# Processing Record 13 of Set 7 | tessalit
# Processing Record 14 of Set 7 | saldanha
# Processing Record 15 of Set 7 | baymak
# Processing Record 16 of Set 7 | gornopravdinsk
# Processing Record 17 of Set 7 | lagoa
# Processing Record 18 of Set 7 | tam ky
# Processing Record 19 of Set 7 | soure
# Processing Record 20 of Set 7 | luwuk
# Processing Record 21 of Set 7 | pushkino
# Processing Record 22 of Set 7 | giddalur
# Processing Record 23 of Set 7 | grand gaube
# Processing Record 24 of Set 7 | guaratuba
# Processing Record 25 of Set 7 | sakakah
# Processing Record 26 of Set 7 | kuito
# Processing Record 27 of Set 7 | milot
# Processing Record 28 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 7 | darlowo
# Processing Record 30 of Set 7 | pundaguitan
# Processing Record 31 of Set 7 | coquimbo
# Processing Record 32 of Set 7 | leh
# Processing Record 33 of Set 7 | turukhansk
# Processing Record 34 of Set 7 | bay roberts
# Processing Record 35 of Set 7 | iqaluit
# Processing Record 36 of Set 7 | honiara
# Processing Record 37 of Set 7 | preobrazheniye
# Processing Record 38 of Set 7 | alcains
# Processing Record 39 of Set 7 | saint marys
# Processing Record 40 of Set 7 | ajdabiya
# Processing Record 41 of Set 7 | xichang
# Processing Record 42 of Set 7 | isangel
# Processing Record 43 of Set 7 | moose factory
# Processing Record 44 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 7 | hukuntsi
# Processing Record 46 of Set 7 | nanortalik
# Processing Record 47 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 48 of Set 7 | jinka
# Processing Record 49 of Set 7 | brigantine
# Processing Record 50 of Set 7 | pandaria
# Processing Record 1 of Set 8 | oranjestad
# Processing Record 2 of Set 8 | longyearbyen
# Processing Record 3 of Set 8 | pakenham
# Processing Record 4 of Set 8 | luderitz
# Processing Record 5 of Set 8 | okato
# Processing Record 6 of Set 8 | auki
# Processing Record 7 of Set 8 | diamantino
# Processing Record 8 of Set 8 | mayya
# Processing Record 9 of Set 8 | lac du bonnet
# Processing Record 10 of Set 8 | upernavik
# Processing Record 11 of Set 8 | zhigansk
# Processing Record 12 of Set 8 | tamisan
# Processing Record 13 of Set 8 | anadyr
# Processing Record 14 of Set 8 | bulgan
# Processing Record 15 of Set 8 | adrar
# Processing Record 16 of Set 8 | pangnirtung
# Processing Record 17 of Set 8 | boksitogorsk
# Processing Record 18 of Set 8 | khorixas
# Processing Record 19 of Set 8 | pavilosta
# Processing Record 20 of Set 8 | tamandare
# Processing Record 21 of Set 8 | codrington
# Processing Record 22 of Set 8 | klaksvik
# Processing Record 23 of Set 8 | bobrovytsya
# Processing Record 24 of Set 8 | warmbad
# Processing Record 25 of Set 8 | wilmington
# Processing Record 26 of Set 8 | gizo
# Processing Record 27 of Set 8 | tacuarembo
# Processing Record 28 of Set 8 | yomou
# Processing Record 29 of Set 8 | aguimes
# Processing Record 30 of Set 8 | camana
# Processing Record 31 of Set 8 | tahta
# Processing Record 32 of Set 8 | kushima
# Processing Record 33 of Set 8 | pankovka
# Processing Record 34 of Set 8 | dillon
# Processing Record 35 of Set 8 | casa grande
# Processing Record 36 of Set 8 | mandera
# Processing Record 37 of Set 8 | atoyac
# Processing Record 38 of Set 8 | noyabrsk
# Processing Record 39 of Set 8 | rincon
# Processing Record 40 of Set 8 | mareeba
# Processing Record 41 of Set 8 | ibitinga
# Processing Record 42 of Set 8 | shenzhen
# Processing Record 43 of Set 8 | tonantins
# Processing Record 44 of Set 8 | dunedin
# Processing Record 45 of Set 8 | chone
# Processing Record 46 of Set 8 | zhuozhou
# City not found. Skipping...
# Processing Record 47 of Set 8 | talnakh
# Processing Record 48 of Set 8 | nelson bay
# Processing Record 49 of Set 8 | okhotsk
# Processing Record 50 of Set 8 | luanda
# Processing Record 1 of Set 9 | conceicao do araguaia
# Processing Record 2 of Set 9 | okmulgee
# Processing Record 3 of Set 9 | waingapu
# Processing Record 4 of Set 9 | fez
# Processing Record 5 of Set 9 | bagdarin
# Processing Record 6 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 9 | chimbote
# Processing Record 8 of Set 9 | kigoma
# Processing Record 9 of Set 9 | nerchinskiy zavod
# Processing Record 10 of Set 9 | te anau
# Processing Record 11 of Set 9 | tecoanapa
# Processing Record 12 of Set 9 | kimparana
# Processing Record 13 of Set 9 | vostok
# Processing Record 14 of Set 9 | moerai
# Processing Record 15 of Set 9 | san quintin
# Processing Record 16 of Set 9 | panguna
# Processing Record 17 of Set 9 | saint-leu
# Processing Record 18 of Set 9 | kosovska mitrovica
# Processing Record 19 of Set 9 | ubala
# Processing Record 20 of Set 9 | cidreira
# Processing Record 21 of Set 9 | suba
# Processing Record 22 of Set 9 | meiganga
# Processing Record 23 of Set 9 | alekseyevsk
# Processing Record 24 of Set 9 | dakar
# Processing Record 25 of Set 9 | ayolas
# Processing Record 26 of Set 9 | henties bay
# Processing Record 27 of Set 9 | vrangel
# Processing Record 28 of Set 9 | porto novo
# Processing Record 29 of Set 9 | korla
# Processing Record 30 of Set 9 | mont-de-marsan
# Processing Record 31 of Set 9 | gao
# Processing Record 32 of Set 9 | delmas
# Processing Record 33 of Set 9 | nuuk
# Processing Record 34 of Set 9 | wanxian
# Processing Record 35 of Set 9 | la rioja
# Processing Record 36 of Set 9 | gobabis
# Processing Record 37 of Set 9 | victoria
# Processing Record 38 of Set 9 | silvassa
# Processing Record 39 of Set 9 | gimli
# Processing Record 40 of Set 9 | port keats
# Processing Record 41 of Set 9 | wasilla
# Processing Record 42 of Set 9 | abu kamal
# Processing Record 43 of Set 9 | ust-kulom
# Processing Record 44 of Set 9 | cascavel
# Processing Record 45 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 46 of Set 9 | pierre
# Processing Record 47 of Set 9 | vera cruz
# Processing Record 48 of Set 9 | damietta
# Processing Record 49 of Set 9 | lavrentiya
# Processing Record 50 of Set 9 | sao joao da barra
# Processing Record 1 of Set 10 | aklavik
# Processing Record 2 of Set 10 | dukat
# Processing Record 3 of Set 10 | monte azul
# Processing Record 4 of Set 10 | masaguisi
# Processing Record 5 of Set 10 | jadu
# Processing Record 6 of Set 10 | katsuura
# Processing Record 7 of Set 10 | chuy
# Processing Record 8 of Set 10 | nome
# Processing Record 9 of Set 10 | adamas
# Processing Record 10 of Set 10 | batemans bay
# Processing Record 11 of Set 10 | iquitos
# Processing Record 12 of Set 10 | xochistlahuaca
# Processing Record 13 of Set 10 | shelburne
# Processing Record 14 of Set 10 | huicheng
# Processing Record 15 of Set 10 | lady frere
# Processing Record 16 of Set 10 | maine-soroa
# Processing Record 17 of Set 10 | tangi
# Processing Record 18 of Set 10 | salinopolis
# Processing Record 19 of Set 10 | bonthe
# Processing Record 20 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 21 of Set 10 | diego de almagro
# Processing Record 22 of Set 10 | hearst
# Processing Record 23 of Set 10 | hailey
# Processing Record 24 of Set 10 | meulaboh
# Processing Record 25 of Set 10 | tura
# Processing Record 26 of Set 10 | kuruman
# Processing Record 27 of Set 10 | seondha
# Processing Record 28 of Set 10 | zhezkazgan
# Processing Record 29 of Set 10 | cordoba
# Processing Record 30 of Set 10 | jujuy
# City not found. Skipping...
# Processing Record 31 of Set 10 | amapa
# Processing Record 32 of Set 10 | bundibugyo
# Processing Record 33 of Set 10 | dwarka
# Processing Record 34 of Set 10 | sept-iles
# Processing Record 35 of Set 10 | savelugu
# Processing Record 36 of Set 10 | lamar
# Processing Record 37 of Set 10 | loyabad
# City not found. Skipping...
# Processing Record 38 of Set 10 | ostrovnoy
# Processing Record 39 of Set 10 | mezen
# Processing Record 40 of Set 10 | baturaja
# Processing Record 41 of Set 10 | santo antonio do ica
# Processing Record 42 of Set 10 | upington
# Processing Record 43 of Set 10 | yendi
# Processing Record 44 of Set 10 | la ronge
# Processing Record 45 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 46 of Set 10 | san andres
# Processing Record 47 of Set 10 | puerto baquerizo moreno
# Processing Record 48 of Set 10 | kyabram
# Processing Record 49 of Set 10 | benguela
# Processing Record 50 of Set 10 | synya
# Processing Record 1 of Set 11 | talaya
# Processing Record 2 of Set 11 | hami
# Processing Record 3 of Set 11 | jiroft
# City not found. Skipping...
# Processing Record 4 of Set 11 | maceio
# Processing Record 5 of Set 11 | inhambane
# Processing Record 6 of Set 11 | cravinhos
# Processing Record 7 of Set 11 | guangzhou
# Processing Record 8 of Set 11 | verkhnevilyuysk
# Processing Record 9 of Set 11 | plettenberg bay
# Processing Record 10 of Set 11 | ambilobe
# Processing Record 11 of Set 11 | neryungri
# Processing Record 12 of Set 11 | neiafu
# Processing Record 13 of Set 11 | yenagoa
# Processing Record 14 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 15 of Set 11 | armacao dos buzios
# City not found. Skipping...
# Processing Record 16 of Set 11 | port hueneme
# Processing Record 17 of Set 11 | cozumel
# Processing Record 18 of Set 11 | veraval
# Processing Record 19 of Set 11 | sao felix do xingu
# Processing Record 20 of Set 11 | kribi
# Processing Record 21 of Set 11 | maunabo
# Processing Record 22 of Set 11 | walvis bay
# Processing Record 23 of Set 11 | saint george
# Processing Record 24 of Set 11 | rio gallegos
# Processing Record 25 of Set 11 | saint-augustin
# Processing Record 26 of Set 11 | puerto del rosario
# Processing Record 27 of Set 11 | skawina
# Processing Record 28 of Set 11 | santa isabel do rio negro
# Processing Record 29 of Set 11 | sijunjung
# Processing Record 30 of Set 11 | jalu
# Processing Record 31 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 32 of Set 11 | fairbanks
# Processing Record 33 of Set 11 | tooele
# Processing Record 34 of Set 11 | novoorsk
# Processing Record 35 of Set 11 | izberbash
# Processing Record 36 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 11 | portland
# Processing Record 38 of Set 11 | gostyn
# Processing Record 39 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 40 of Set 11 | tayga
# Processing Record 41 of Set 11 | great yarmouth
# Processing Record 42 of Set 11 | faridpur
# Processing Record 43 of Set 11 | sexsmith
# Processing Record 44 of Set 11 | turinsk
# Processing Record 45 of Set 11 | abong mbang
# Processing Record 46 of Set 11 | emilio carranza
# Processing Record 47 of Set 11 | quilali
# Processing Record 48 of Set 11 | sibu
# Processing Record 49 of Set 11 | asfi
# Processing Record 50 of Set 11 | gimbi
# Processing Record 1 of Set 12 | bonavista
# Processing Record 2 of Set 12 | aksu
# Processing Record 3 of Set 12 | oga
# Processing Record 4 of Set 12 | bandiagara
# Processing Record 5 of Set 12 | college
# Processing Record 6 of Set 12 | berezovyy
# Processing Record 7 of Set 12 | paita
# Processing Record 8 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 9 of Set 12 | santa rosa
# Processing Record 10 of Set 12 | gatesville
# Processing Record 11 of Set 12 | abha
# Processing Record 12 of Set 12 | praia da vitoria
# Processing Record 13 of Set 12 | halmstad
# Processing Record 14 of Set 12 | tubmanburg
# Processing Record 15 of Set 12 | port hardy
# Processing Record 16 of Set 12 | port lincoln
# Processing Record 17 of Set 12 | tortosa
# Processing Record 18 of Set 12 | bhinga
# Processing Record 19 of Set 12 | kupang
# Processing Record 20 of Set 12 | cabedelo
# Processing Record 21 of Set 12 | slave lake
# Processing Record 22 of Set 12 | eureka
# Processing Record 23 of Set 12 | whitehorse
# Processing Record 24 of Set 12 | tateyama
# Processing Record 25 of Set 12 | obo
# Processing Record 26 of Set 12 | beira
# Processing Record 27 of Set 12 | the valley
# Processing Record 28 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 29 of Set 12 | kropotkin
# Processing Record 30 of Set 12 | puerto penasco
# Processing Record 31 of Set 12 | mato verde
# Processing Record 32 of Set 12 | tiarei
# Processing Record 33 of Set 12 | san carlos de bariloche
# Processing Record 34 of Set 12 | carman
# Processing Record 35 of Set 12 | shimoda
# Processing Record 36 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 37 of Set 12 | lanzhou
# Processing Record 38 of Set 12 | rocha
# Processing Record 39 of Set 12 | tiznit
# Processing Record 40 of Set 12 | yaan
# Processing Record 41 of Set 12 | barroualie
# City not found. Skipping...
# Processing Record 42 of Set 12 | zyryanka
# Processing Record 43 of Set 12 | huinan
# Processing Record 44 of Set 12 | margate
# Processing Record 45 of Set 12 | katangli
# Processing Record 46 of Set 12 | hualmay
# Processing Record 47 of Set 12 | kurchum
# Processing Record 48 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 12 | liverpool
# Processing Record 50 of Set 12 | novo aripuana
# Processing Record 1 of Set 13 | ketchikan
# Processing Record 2 of Set 13 | sechura
# Processing Record 3 of Set 13 | santa cruz del sur
# Processing Record 4 of Set 13 | nykoping
# Processing Record 5 of Set 13 | pisco
# Processing Record 6 of Set 13 | kirensk
# Processing Record 7 of Set 13 | bend
# Processing Record 8 of Set 13 | birao
# Processing Record 9 of Set 13 | oum hadjer
# Processing Record 10 of Set 13 | areosa
# Processing Record 11 of Set 13 | nicoya
# Processing Record 12 of Set 13 | fortuna foothills
# Processing Record 13 of Set 13 | corralillo
# Processing Record 14 of Set 13 | linhares
# Processing Record 15 of Set 13 | jeremoabo
# Processing Record 16 of Set 13 | quincy
# Processing Record 17 of Set 13 | touros
# Processing Record 18 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 19 of Set 13 | lukovetskiy
# Processing Record 20 of Set 13 | anloga
# Processing Record 21 of Set 13 | yulara
# Processing Record 22 of Set 13 | kuytun
# Processing Record 23 of Set 13 | calamar
# Processing Record 24 of Set 13 | manadhoo
# Processing Record 25 of Set 13 | samarinda
# Processing Record 26 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 27 of Set 13 | vilhena
# Processing Record 28 of Set 13 | ardistan
# City not found. Skipping...
# Processing Record 29 of Set 13 | nong khai
# Processing Record 30 of Set 13 | seoul
# Processing Record 31 of Set 13 | jiwani
# Processing Record 32 of Set 13 | tromso
# Processing Record 33 of Set 13 | paamiut
# Processing Record 34 of Set 13 | chipiona
# Processing Record 35 of Set 13 | lubao
# Processing Record 36 of Set 13 | pak phanang
# Processing Record 37 of Set 13 | kaabong
# Processing Record 38 of Set 13 | tubuala
# Processing Record 39 of Set 13 | khor
# Processing Record 40 of Set 13 | grand-santi
# Processing Record 41 of Set 13 | formosa do rio preto
# Processing Record 42 of Set 13 | flin flon
# Processing Record 43 of Set 13 | salair
# Processing Record 44 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 45 of Set 13 | rawson
# Processing Record 46 of Set 13 | upata
# Processing Record 47 of Set 13 | martaban
# Processing Record 48 of Set 13 | belmonte
# Processing Record 49 of Set 13 | la paz
# Processing Record 50 of Set 13 | ukiah
# Processing Record 1 of Set 14 | zhangjiakou
# Processing Record 2 of Set 14 | viedma
# Processing Record 3 of Set 14 | nemuro
# Processing Record 4 of Set 14 | port moresby
# Processing Record 5 of Set 14 | sharkan
# Processing Record 6 of Set 14 | bury saint edmunds
# City not found. Skipping...
# Processing Record 7 of Set 14 | maniitsoq
# Processing Record 8 of Set 14 | scarborough
# Processing Record 9 of Set 14 | enshi
# Processing Record 10 of Set 14 | sedelnikovo
# City not found. Skipping...
# Processing Record 11 of Set 14 | scalloway
# City not found. Skipping...
# Processing Record 12 of Set 14 | itarema
# Processing Record 13 of Set 14 | toftir
# City not found. Skipping...
# Processing Record 14 of Set 14 | matagami
# Processing Record 15 of Set 14 | port blair
# Processing Record 16 of Set 14 | cascais
# Processing Record 17 of Set 14 | kununurra
# Processing Record 18 of Set 14 | naze
# Processing Record 19 of Set 14 | fuerte olimpo
# Processing Record 20 of Set 14 | north platte
# Processing Record 21 of Set 14 | wajid
# Processing Record 22 of Set 14 | fianga
# City not found. Skipping...
# Processing Record 23 of Set 14 | sakata
# Processing Record 24 of Set 14 | burns lake
# Processing Record 25 of Set 14 | mkushi
# Processing Record 26 of Set 14 | nishihara
# Processing Record 27 of Set 14 | livny
# Processing Record 28 of Set 14 | kapoeta
# Processing Record 29 of Set 14 | chernyshevskiy
# Processing Record 30 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 31 of Set 14 | la palma
# Processing Record 32 of Set 14 | hervey bay
# Processing Record 33 of Set 14 | ayotzintepec
# Processing Record 34 of Set 14 | unhel
# Processing Record 35 of Set 14 | ochakiv
# Processing Record 36 of Set 14 | elko
# Processing Record 37 of Set 14 | san jeronimo
# Processing Record 38 of Set 14 | falealupo
# City not found. Skipping...
# Processing Record 39 of Set 14 | lethem
# Processing Record 40 of Set 14 | churapcha
# Processing Record 41 of Set 14 | hanna
# Processing Record 42 of Set 14 | dong hoi
# Processing Record 43 of Set 14 | ulaanbaatar
# Processing Record 44 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 14 | mackenzie
# Processing Record 46 of Set 14 | solnechnyy
# Processing Record 47 of Set 14 | aswan
# Processing Record 48 of Set 14 | qaqortoq
# Processing Record 49 of Set 14 | rock sound
# Processing Record 50 of Set 14 | andalucia
# Processing Record 1 of Set 15 | mackay
# Processing Record 2 of Set 15 | dabakala
# Processing Record 3 of Set 15 | turayf
# Processing Record 4 of Set 15 | dabola
# Processing Record 5 of Set 15 | chandia
# Processing Record 6 of Set 15 | valvedditturai
# Processing Record 7 of Set 15 | muros
# Processing Record 8 of Set 15 | torres
# Processing Record 9 of Set 15 | aasiaat
# Processing Record 10 of Set 15 | biak
# Processing Record 11 of Set 15 | huarmey
# Processing Record 12 of Set 15 | noumea
# Processing Record 13 of Set 15 | pochinok
# Processing Record 14 of Set 15 | mayo
# Processing Record 15 of Set 15 | mahaicony
# City not found. Skipping...
# Processing Record 16 of Set 15 | ballarat
# Processing Record 17 of Set 15 | pringsewu
# Processing Record 18 of Set 15 | port shepstone
# Processing Record 19 of Set 15 | aviles
# Processing Record 20 of Set 15 | sokolo
# Processing Record 21 of Set 15 | loudi
# Processing Record 22 of Set 15 | teguldet
# Processing Record 23 of Set 15 | calabozo
# Processing Record 24 of Set 15 | ancud
# Processing Record 25 of Set 15 | pekan
# Processing Record 26 of Set 15 | arak
# Processing Record 27 of Set 15 | north bend
# Processing Record 28 of Set 15 | barcelos
# Processing Record 29 of Set 15 | marystown
# Processing Record 30 of Set 15 | saint-louis
# Processing Record 31 of Set 15 | agadez
# Processing Record 32 of Set 15 | gravdal
# Processing Record 33 of Set 15 | kattivakkam
# Processing Record 34 of Set 15 | bogale
# Processing Record 35 of Set 15 | vila velha
# Processing Record 36 of Set 15 | tigil
# Processing Record 37 of Set 15 | kalabo
# Processing Record 38 of Set 15 | donskoye
# Processing Record 39 of Set 15 | sawakin
# Processing Record 40 of Set 15 | los planes
# Processing Record 41 of Set 15 | pathein
# Processing Record 42 of Set 15 | fevralsk
# City not found. Skipping...
# Processing Record 43 of Set 15 | malanje
# Processing Record 44 of Set 15 | navabad
# City not found. Skipping...
# Processing Record 45 of Set 15 | namatanai
# Processing Record 46 of Set 15 | kosh-agach
# Processing Record 47 of Set 15 | samur
# Processing Record 48 of Set 15 | antalaha
# Processing Record 49 of Set 15 | ust-ishim
# Processing Record 50 of Set 15 | providencia
# Processing Record 1 of Set 16 | lensk
# Processing Record 2 of Set 16 | arica
# Processing Record 3 of Set 16 | constantine
# Processing Record 4 of Set 16 | baruun-urt
# Processing Record 5 of Set 16 | biryusinsk
# Processing Record 6 of Set 16 | porto nacional
# Processing Record 7 of Set 16 | niteroi
# Processing Record 8 of Set 16 | kutum
# Processing Record 9 of Set 16 | paka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 695

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hamilton      US  39.1834  -84.5333     28.99        86          90
# 1   Port Alfred      ZA -33.5906   26.8910     65.44        71          73
# 2    Nikolskoye      RU  59.7035   30.7861     25.00        93          75
# 3         Pevek      RU  69.7008  170.3133      4.62        90         100
# 4   New Norfolk      AU -42.7826  147.0587     70.00        50          60
# 5  San Patricio      US  28.0170  -97.5169     55.40        57           1
# 6      Amargosa      BR -13.0303  -39.6047     68.86        98          47
# 7       Rikitea      PF -23.1203 -134.9692     78.71        75          97
# 8     Busselton      AU -33.6500  115.3333     93.00        33           0
# 9     Cape Town      ZA -33.9258   18.4232     66.00        67           0
#
#    Wind Speed Current Description
# 0       11.50                snow
# 1       17.52       broken clouds
# 2        4.47                snow
# 3       23.22          light snow
# 4        3.00       broken clouds
# 5        4.61           clear sky
# 6        3.71    scattered clouds
# 7       13.33     overcast clouds
# 8        4.63           clear sky
# 9        4.61           clear sky

# %%
# Create the output file (CSV).
output_challenge_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_challenge_file, index_label="City_ID")
